# %% [markdown]
# Guia 4 - Limpieza y Filtrado de Datos -

# %%
import pandas as pd

# %%
arboles = pd.read_csv("https://raw.githubusercontent.com/MumukiProject/datasets/master/arbolado-publico-lineal.csv")

# %%
arboles
# Out:
#              long        lat site_type      tree_id  height  diameter  \
# 0      -58.389059 -34.620026     Árbol       2430.0     7.0      20.0
# 1      -58.389211 -34.620034     Árbol       2431.0     8.0      33.0
# 2      -58.389269 -34.620037     Árbol       2432.0     2.0       3.0
# 3      -58.389525 -34.620052     Árbol       2433.0     9.0      17.0
# 4      -58.389608 -34.620057     Árbol       2434.0     6.0      13.0
# ...           ...        ...       ...          ...     ...       ...
# 372689 -58.493294 -34.623746     Árbol  938000239.0    10.0      52.0
# 372690 -58.493241 -34.623788     Árbol  938000240.0    11.0      60.0
# 372691 -58.493176 -34.623840     Árbol  938000241.0    10.0      56.0
# 372692 -58.493116 -34.623887     Árbol  938000242.0    10.0      58.0
# 372693 -58.493086 -34.624042     Árbol  938000243.0     3.0       5.0
#
#         inclination  species_id   fam_name       gen_name  \
# 0              17.0         1.0   Oleáceas       Fraxinus
# ...

# %%
arboles["height"] >= 7
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 372689     True
# 372690     True
# 372691     True
# 372692     True
# 372693    False
# Name: height, Length: 372694, dtype: bool

# %% [markdown]
# Obtuvimos un Series de booleanos

# %% [markdown]
# Por ejemplo, con ella podemos filtrar datos de nuestro DataFrame original y obtener uno nuevo, con sólo las filas que cumplan la condición. La forma de hacerlo es colocando una condición entre corchetes de la siguiente forma: tabla[condicion]

# %%
arboles["neighbourhood"] == "Palermo"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 372689    True
# 372690    True
# 372691    True
# 372692    True
# 372693    True
# Name: neighbourhood, Length: 372694, dtype: bool

# %% [markdown]
# Combinamos Filtrados --> como in, str.startswitho, str.endswith
#
# si ahora buscáramos a todas las personas que tengan un nombre terminado con la letra a deberíamos hacer:
#
# personas[personas["nombre"].str.endswith("a")]
